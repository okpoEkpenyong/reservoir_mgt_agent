# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Reservoir Agent – Demo Notebook\n",
    "This notebook demonstrates:\n",
    "- Loading an example ECLIPSE deck\n",
    "- Running the DeckParser\n",
    "- Running QC rules\n",
    "- Producing an Agent analysis report"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "execution_count": null,
   "outputs": [],
   "source": [
    "from reservoir_agent.parsers.deck_parser import DeckParser\n",
    "from reservoir_agent.agent.reservoir_agent import ReservoirAgent"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "execution_count": null,
   "outputs": [],
   "source": [
    "parser = DeckParser('examples/example_deck.DATA')\n",
    "agent = ReservoirAgent()\n",
    "result = agent.analyze_deck(parser)\n",
    "result"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
